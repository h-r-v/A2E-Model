# %%
'''
https://github.com/vedantagarwal4
https://github.com/h-r-v
'''

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
import tensorflow as tf
seed = 1

# %%
datafile = os.path.join( os.getcwd(), "Clean Data")
datafile = os.path.join( datafile, "data.csv")

df = pd.read_csv(datafile)

# %%
df.shape, df.label.nunique()
# Out:
# ((1392, 2), 26)

# %%
# TRAIN-VAL-TEST
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.1, stratify=df.label)
train, validate = train_test_split(train, test_size=0.11, stratify=train.label)

train.shape, validate.shape, test.shape
# Out:
# ((1114, 2), (138, 2), (140, 2))

# %%
labels = sorted(list(train.label.unique()))

import seaborn as sns
sns.countplot(x='label',data=train, order=labels)

# %%
sns.countplot(x='label', data=validate, order=labels)

# %%
sns.countplot(x='label', data=test, order=labels)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import preprocess_input

# %%
#AUGMENTATION

batch_size=16
target_size=(100, 100)
color_mode="rgb"

train_datagen = ImageDataGenerator(
        preprocessing_function=preprocess_input,
        rescale=1./255,
        zoom_range=0.1,
        horizontal_flip=True,
        rotation_range=10,
        width_shift_range = 0.1,
        height_shift_range = 0.1,
        brightness_range = (0.5,1)
)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train,
    directory=None,
    x_col="path",
    y_col="label",
    target_size=target_size,
    color_mode=color_mode,
    class_mode="categorical",
    batch_size=batch_size,
    #save_to_dir = "preview",
    #save_prefix = "preview",
    #save_format = "png"
)

test_datagen = ImageDataGenerator(rescale=1./255)

validation_generator = test_datagen.flow_from_dataframe(
    dataframe=validate,
    directory=None,
    x_col="path",
    y_col="label",
    target_size=target_size,
    color_mode=color_mode,
    class_mode="categorical",
    batch_size=batch_size,
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test,
    directory=None,
    x_col="path",
    y_col="label",
    target_size=target_size,
    color_mode=color_mode,
    class_mode="categorical",
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 1114 validated image filenames belonging to 26 classes.
# Found 138 validated image filenames belonging to 26 classes.
# Found 140 validated image filenames belonging to 26 classes.

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential

# %%
#SHALLOW CNN
def create_cnn(pooling='avg'):
    d=0.1
    base_model = VGG16(include_top=False, weights='imagenet', input_shape=(100,100,3), pooling=pooling) 
    base_model.trainable=False
    
    model = Sequential()
    model.add(base_model)
    
    model.add(Flatten())
    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(Dropout(d))
    model.add(Dense(26))
    model.add(Activation('softmax'))
    
    model.compile(
                  loss='categorical_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(learning_rate=0.001, amsgrad=True),
                  metrics=['acc','categorical_accuracy']
                )
    
    model.summary()
    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor = 'val_loss', mode = 'min', patience=25, restore_best_weights=True)

# %%
model = create_cnn()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 512)               14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               65664
# _________________________________________________________________
# activation (Activation)      (None, 128)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 26)                3354
# _________________________________________________________________
# activation_1 (Activation)    (None, 26)                0
# =================================================================
# Total params: 14,783,706
# Trainable params: 69,018
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model_hist = model.fit( train_generator, 
                                 steps_per_epoch=train.shape[0] // batch_size, 
                                 epochs=150, 
                                 validation_data=validation_generator, 
                                 validation_steps=validate.shape[0] // batch_size,
                                 callbacks=[early_stop]
                      )
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 69 steps, validate for 8 steps
# Epoch 1/150
# 69/69 [==============================] - 8s 114ms/step - loss: 3.2576 - acc: 0.0592 - categorical_accuracy: 0.0592 - val_loss: 3.0265 - val_acc: 0.1953 - val_categorical_accuracy: 0.1953
# Epoch 2/150
# 69/69 [==============================] - 6s 90ms/step - loss: 2.9873 - acc: 0.1803 - categorical_accuracy: 0.1803 - val_loss: 2.7369 - val_acc: 0.3047 - val_categorical_accuracy: 0.3047
# Epoch 3/150
# 69/69 [==============================] - 6s 87ms/step - loss: 2.7184 - acc: 0.2996 - categorical_accuracy: 0.2996 - val_loss: 2.4701 - val_acc: 0.2891 - val_categorical_accuracy: 0.2891
# Epoch 4/150
# 69/69 [==============================] - 6s 84ms/step - loss: 2.4542 - acc: 0.3379 - categorical_accuracy: 0.3379 - val_loss: 2.1449 - val_acc: 0.5000 - val_categorical_accuracy: 0.5000
# Epoch 5/150
# 69/69 [==============================] - 6s 84ms/step - loss: 2.2173 - acc: 0.4454 - categorical_accuracy: 0.4454 - val_loss: 1.8719 - val_acc: 0.5625 - val_categorical_accuracy: 0.5625
# Epoch 6/150
# 69/69 [==============================] - 6s 82ms/step - loss: 1.9818 - acc: 0.5000 - categorical_accuracy: 0.5000 - val_loss: 1.6872 - val_acc: 0.5781 - val_categorical_accuracy: 0.5781
# Epoch 7/150
# 69/69 [==============================] - 6s 83ms/step - loss: 1.7967 - acc: 0.5392 - categorical_accuracy: 0.5392 - val_loss: 1.4708 - val_acc: 0.6562 - val_categorical_accuracy: 0.6562
# Epoch 8/150
# 69/69 [==============================] - 6s 82ms/step - loss: 1.6562 - acc: 0.5710 - categorical_accuracy: 0.5710 - val_loss: 1.3538 - val_acc: 0.6328 - val_categorical_accuracy: 0.6328
# Epoch 9/150
# 69/69 [==============================] - 6s 84ms/step - loss: 1.5331 - acc: 0.6211 - categorical_accuracy: 0.6211 - val_loss: 1.2513 - val_acc: 0.6406 - val_categorical_accuracy: 0.6406
# Epoch 10/150
# 69/69 [==============================] - 6s 84ms/step - loss: 1.4062 - acc: 0.6384 - categorical_accuracy: 0.6384 - val_loss: 1.1335 - val_acc: 0.6797 - val_categorical_accuracy: 0.6797
# Epoch 11/150
# 69/69 [==============================] - 6s 84ms/step - loss: 1.3408 - acc: 0.6339 - categorical_accuracy: 0.6339 - val_loss: 1.0357 - val_acc: 0.7344 - val_categorical_accuracy: 0.7344
# Epoch 12/150
# 69/69 [==============================] - 6s 84ms/step - loss: 1.2450 - acc: 0.6667 - categorical_accuracy: 0.6667 - val_loss: 0.9795 - val_acc: 0.7578 - val_categorical_accuracy: 0.7578
# Epoch 13/150
# 69/69 [==============================] - 6s 88ms/step - loss: 1.1825 - acc: 0.6940 - categorical_accuracy: 0.6940 - val_loss: 0.9558 - val_acc: 0.7266 - val_categorical_accuracy: 0.7266
# Epoch 14/150
# 69/69 [==============================] - 6s 85ms/step - loss: 1.0888 - acc: 0.7040 - categorical_accuracy: 0.7040 - val_loss: 0.9023 - val_acc: 0.7578 - val_categorical_accuracy: 0.7578
# Epoch 15/150
# 69/69 [==============================] - 6s 82ms/step - loss: 1.0748 - acc: 0.7086 - categorical_accuracy: 0.7086 - val_loss: 0.8524 - val_acc: 0.7578 - val_categorical_accuracy: 0.7578
# Epoch 16/150
# 69/69 [==============================] - 6s 89ms/step - loss: 1.0016 - acc: 0.7286 - categorical_accuracy: 0.7286 - val_loss: 0.7795 - val_acc: 0.8125 - val_categorical_accuracy: 0.8125
# Epoch 17/150
# 69/69 [==============================] - 6s 89ms/step - loss: 0.9617 - acc: 0.7368 - categorical_accuracy: 0.7368 - val_loss: 0.8082 - val_acc: 0.7656 - val_categorical_accuracy: 0.7656
# Epoch 18/150
# 69/69 [==============================] - 6s 88ms/step - loss: 0.9330 - acc: 0.7341 - categorical_accuracy: 0.7341 - val_loss: 0.7167 - val_acc: 0.8281 - val_categorical_accuracy: 0.8281
# Epoch 19/150
# 69/69 [==============================] - 6s 84ms/step - loss: 0.9007 - acc: 0.7605 - categorical_accuracy: 0.7605 - val_loss: 0.7225 - val_acc: 0.7578 - val_categorical_accuracy: 0.7578
# Epoch 20/150
# 69/69 [==============================] - 6s 85ms/step - loss: 0.8626 - acc: 0.7596 - categorical_accuracy: 0.7596 - val_loss: 0.7126 - val_acc: 0.8125 - val_categorical_accuracy: 0.8125
# Epoch 21/150
# 69/69 [==============================] - 6s 87ms/step - loss: 0.8142 - acc: 0.7714 - categorical_accuracy: 0.7714 - val_loss: 0.6901 - val_acc: 0.8203 - val_categorical_accuracy: 0.8203
# Epoch 22/150
# 69/69 [==============================] - 6s 86ms/step - loss: 0.7870 - acc: 0.7778 - categorical_accuracy: 0.7778 - val_loss: 0.6810 - val_acc: 0.8047 - val_categorical_accuracy: 0.8047
# Epoch 23/150
# 69/69 [==============================] - 6s 85ms/step - loss: 0.7705 - acc: 0.7942 - categorical_accuracy: 0.7942 - val_loss: 0.6428 - val_acc: 0.8125 - val_categorical_accuracy: 0.8125
# Epoch 24/150
# 69/69 [==============================] - 6s 89ms/step - loss: 0.7715 - acc: 0.7914 - categorical_accuracy: 0.7914 - val_loss: 0.6041 - val_acc: 0.8281 - val_categorical_accuracy: 0.8281
# Epoch 25/150
# 69/69 [==============================] - 6s 89ms/step - loss: 0.7208 - acc: 0.8033 - categorical_accuracy: 0.8033 - val_loss: 0.6178 - val_acc: 0.7969 - val_categorical_accuracy: 0.7969
# Epoch 26/150
# 69/69 [==============================] - 6s 89ms/step - loss: 0.7281 - acc: 0.7896 - categorical_accuracy: 0.7896 - val_loss: 0.5955 - val_acc: 0.8125 - val_categorical_accuracy: 0.8125
# Epoch 27/150
# 69/69 [==============================] - 12s 181ms/step - loss: 0.6954 - acc: 0.7878 - categorical_accuracy: 0.7878 - val_loss: 0.5782 - val_acc: 0.8438 - val_categorical_accuracy: 0.8438
# Epoch 28/150
# 69/69 [==============================] - 17s 241ms/step - loss: 0.6701 - acc: 0.7960 - categorical_accuracy: 0.7960 - val_loss: 0.5671 - val_acc: 0.8438 - val_categorical_accuracy: 0.8438
# Epoch 29/150
# 69/69 [==============================] - 15s 214ms/step - loss: 0.6616 - acc: 0.8169 - categorical_accuracy: 0.8169 - val_loss: 0.5650 - val_acc: 0.8594 - val_categorical_accuracy: 0.8594
# Epoch 30/150
# 69/69 [==============================] - 15s 212ms/step - loss: 0.6245 - acc: 0.8233 - categorical_accuracy: 0.8233 - val_loss: 0.5621 - val_acc: 0.8359 - val_categorical_accuracy: 0.8359
# Epoch 31/150
# 69/69 [==============================] - 17s 243ms/step - loss: 0.6137 - acc: 0.8197 - categorical_accuracy: 0.8197 - val_loss: 0.5827 - val_acc: 0.8281 - val_categorical_accuracy: 0.8281
# Epoch 32/150
# 69/69 [==============================] - 17s 244ms/step - loss: 0.5972 - acc: 0.8251 - categorical_accuracy: 0.8251 - val_loss: 0.4966 - val_acc: 0.8359 - val_categorical_accuracy: 0.8359
# Epoch 33/150
# 69/69 [==============================] - 14s 204ms/step - loss: 0.6262 - acc: 0.8060 - categorical_accuracy: 0.8060 - val_loss: 0.5662 - val_acc: 0.8203 - val_categorical_accuracy: 0.8203
# Epoch 34/150
# 69/69 [==============================] - 14s 199ms/step - loss: 0.5690 - acc: 0.8297 - categorical_accuracy: 0.8297 - val_loss: 0.5160 - val_acc: 0.8438 - val_categorical_accuracy: 0.8438
# Epoch 35/150
# 69/69 [==============================] - 8s 112ms/step - loss: 0.5743 - acc: 0.8415 - categorical_accuracy: 0.8415 - val_loss: 0.5150 - val_acc: 0.8516 - val_categorical_accuracy: 0.8516
# Epoch 36/150
# 69/69 [==============================] - 7s 98ms/step - loss: 0.5454 - acc: 0.8415 - categorical_accuracy: 0.8415 - val_loss: 0.5274 - val_acc: 0.8516 - val_categorical_accuracy: 0.8516
# Epoch 37/150
# 69/69 [==============================] - 7s 96ms/step - loss: 0.5527 - acc: 0.8452 - categorical_accuracy: 0.8452 - val_loss: 0.4824 - val_acc: 0.8203 - val_categorical_accuracy: 0.8203
# Epoch 38/150
# 69/69 [==============================] - 7s 99ms/step - loss: 0.5370 - acc: 0.8388 - categorical_accuracy: 0.8388 - val_loss: 0.5292 - val_acc: 0.8359 - val_categorical_accuracy: 0.8359
# Epoch 39/150
# 69/69 [==============================] - 7s 107ms/step - loss: 0.5367 - acc: 0.8443 - categorical_accuracy: 0.8443 - val_loss: 0.4984 - val_acc: 0.8438 - val_categorical_accuracy: 0.8438
# Epoch 40/150
# 69/69 [==============================] - 34s 490ms/step - loss: 0.5333 - acc: 0.8352 - categorical_accuracy: 0.8352 - val_loss: 0.5031 - val_acc: 0.8203 - val_categorical_accuracy: 0.8203
# Epoch 41/150
# 69/69 [==============================] - 8s 113ms/step - loss: 0.5131 - acc: 0.8443 - categorical_accuracy: 0.8443 - val_loss: 0.4746 - val_acc: 0.8516 - val_categorical_accuracy: 0.8516
# Epoch 42/150
# 69/69 [==============================] - 6s 82ms/step - loss: 0.4954 - acc: 0.8579 - categorical_accuracy: 0.8579 - val_loss: 0.4611 - val_acc: 0.8594 - val_categorical_accuracy: 0.8594
# Epoch 43/150
# 69/69 [==============================] - 6s 81ms/step - loss: 0.4890 - acc: 0.8497 - categorical_accuracy: 0.8497 - val_loss: 0.4400 - val_acc: 0.8516 - val_categorical_accuracy: 0.8516
# Epoch 44/150
# 69/69 [==============================] - 6s 81ms/step - loss: 0.4697 - acc: 0.8652 - categorical_accuracy: 0.8652 - val_loss: 0.4495 - val_acc: 0.8516 - val_categorical_accuracy: 0.8516
# Epoch 45/150
# 69/69 [==============================] - 6s 86ms/step - loss: 0.4661 - acc: 0.8679 - categorical_accuracy: 0.8679 - val_loss: 0.4950 - val_acc: 0.8281 - val_categorical_accuracy: 0.8281
# Epoch 46/150
# 69/69 [==============================] - 6s 93ms/step - loss: 0.4656 - acc: 0.8597 - categorical_accuracy: 0.8597 - val_loss: 0.4708 - val_acc: 0.8594 - val_categorical_accuracy: 0.8594
# Epoch 47/150
# 69/69 [==============================] - 7s 99ms/step - loss: 0.4663 - acc: 0.8616 - categorical_accuracy: 0.8616 - val_loss: 0.4823 - val_acc: 0.8516 - val_categorical_accuracy: 0.8516
# Epoch 48/150
# 69/69 [==============================] - 7s 94ms/step - loss: 0.4741 - acc: 0.8461 - categorical_accuracy: 0.8461 - val_loss: 0.4806 - val_acc: 0.8438 - val_categorical_accuracy: 0.8438
# Epoch 49/150
# 69/69 [==============================] - 8s 109ms/step - loss: 0.4513 - acc: 0.8770 - categorical_accuracy: 0.8770 - val_loss: 0.4131 - val_acc: 0.8594 - val_categorical_accuracy: 0.8594
# Epoch 50/150
# 69/69 [==============================] - 6s 93ms/step - loss: 0.4719 - acc: 0.8616 - categorical_accuracy: 0.8616 - val_loss: 0.4500 - val_acc: 0.8594 - val_categorical_accuracy: 0.8594
# Epoch 51/150
# 69/69 [==============================] - 6s 94ms/step - loss: 0.4484 - acc: 0.8597 - categorical_accuracy: 0.8597 - val_loss: 0.4066 - val_acc: 0.8672 - val_categorical_accuracy: 0.8672
# Epoch 52/150
# 69/69 [==============================] - 6s 93ms/step - loss: 0.4338 - acc: 0.8643 - categorical_accuracy: 0.8643 - val_loss: 0.4322 - val_acc: 0.8594 - val_categorical_accuracy: 0.8594
# Epoch 53/150
# 69/69 [==============================] - 7s 97ms/step - loss: 0.4195 - acc: 0.8816 - categorical_accuracy: 0.8816 - val_loss: 0.3947 - val_acc: 0.8672 - val_categorical_accuracy: 0.8672
# Epoch 54/150
# 69/69 [==============================] - 6s 93ms/step - loss: 0.4244 - acc: 0.8579 - categorical_accuracy: 0.8579 - val_loss: 0.4572 - val_acc: 0.8516 - val_categorical_accuracy: 0.8516
# Epoch 55/150
# 69/69 [==============================] - 7s 95ms/step - loss: 0.4312 - acc: 0.8734 - categorical_accuracy: 0.8734 - val_loss: 0.4189 - val_acc: 0.8516 - val_categorical_accuracy: 0.8516
# Epoch 56/150
# 69/69 [==============================] - 7s 95ms/step - loss: 0.4369 - acc: 0.8661 - categorical_accuracy: 0.8661 - val_loss: 0.4231 - val_acc: 0.8672 - val_categorical_accuracy: 0.8672
# Epoch 57/150
# 69/69 [==============================] - 6s 93ms/step - loss: 0.3959 - acc: 0.8825 - categorical_accuracy: 0.8825 - val_loss: 0.4985 - val_acc: 0.8359 - val_categorical_accuracy: 0.8359
# Epoch 58/150
# 69/69 [==============================] - 7s 96ms/step - loss: 0.4042 - acc: 0.8770 - categorical_accuracy: 0.8770 - val_loss: 0.4424 - val_acc: 0.8359 - val_categorical_accuracy: 0.8359
# Epoch 59/150
# 69/69 [==============================] - 7s 99ms/step - loss: 0.3659 - acc: 0.9007 - categorical_accuracy: 0.9007 - val_loss: 0.4213 - val_acc: 0.8359 - val_categorical_accuracy: 0.8359
# Epoch 60/150
# 69/69 [==============================] - 7s 101ms/step - loss: 0.3888 - acc: 0.8780 - categorical_accuracy: 0.8780 - val_loss: 0.3914 - val_acc: 0.8672 - val_categorical_accuracy: 0.8672
# Epoch 61/150
# 69/69 [==============================] - 7s 96ms/step - loss: 0.3920 - acc: 0.8798 - categorical_accuracy: 0.8798 - val_loss: 0.3367 - val_acc: 0.8984 - val_categorical_accuracy: 0.8984
# Epoch 62/150
# 69/69 [==============================] - 6s 94ms/step - loss: 0.3913 - acc: 0.8770 - categorical_accuracy: 0.8770 - val_loss: 0.3636 - val_acc: 0.8672 - val_categorical_accuracy: 0.8672
# Epoch 63/150
# 69/69 [==============================] - 7s 95ms/step - loss: 0.3517 - acc: 0.8953 - categorical_accuracy: 0.8953 - val_loss: 0.4093 - val_acc: 0.8438 - val_categorical_accuracy: 0.8438
# Epoch 64/150
# 69/69 [==============================] - 7s 96ms/step - loss: 0.3567 - acc: 0.8907 - categorical_accuracy: 0.8907 - val_loss: 0.4320 - val_acc: 0.8594 - val_categorical_accuracy: 0.8594
# Epoch 65/150
# 69/69 [==============================] - 7s 99ms/step - loss: 0.3619 - acc: 0.8871 - categorical_accuracy: 0.8871 - val_loss: 0.4172 - val_acc: 0.8750 - val_categorical_accuracy: 0.8750
# Epoch 66/150
# 69/69 [==============================] - 6s 94ms/step - loss: 0.3522 - acc: 0.8925 - categorical_accuracy: 0.8925 - val_loss: 0.4210 - val_acc: 0.8359 - val_categorical_accuracy: 0.8359
# Epoch 67/150
# 69/69 [==============================] - 7s 95ms/step - loss: 0.3621 - acc: 0.8770 - categorical_accuracy: 0.8770 - val_loss: 0.4292 - val_acc: 0.8438 - val_categorical_accuracy: 0.8438
# Epoch 68/150
# 69/69 [==============================] - 7s 95ms/step - loss: 0.3697 - acc: 0.8852 - categorical_accuracy: 0.8852 - val_loss: 0.3829 - val_acc: 0.8828 - val_categorical_accuracy: 0.8828
# Epoch 69/150
# 69/69 [==============================] - 7s 96ms/step - loss: 0.3383 - acc: 0.8953 - categorical_accuracy: 0.8953 - val_loss: 0.3603 - val_acc: 0.8906 - val_categorical_accuracy: 0.8906
# Epoch 70/150
# 69/69 [==============================] - 7s 98ms/step - loss: 0.3432 - acc: 0.8880 - categorical_accuracy: 0.8880 - val_loss: 0.3940 - val_acc: 0.8828 - val_categorical_accuracy: 0.8828
# Epoch 71/150
# 69/69 [==============================] - 7s 100ms/step - loss: 0.3490 - acc: 0.8980 - categorical_accuracy: 0.8980 - val_loss: 0.4260 - val_acc: 0.8594 - val_categorical_accuracy: 0.8594
# Epoch 72/150
# 69/69 [==============================] - 7s 97ms/step - loss: 0.3311 - acc: 0.9026 - categorical_accuracy: 0.9026 - val_loss: 0.3802 - val_acc: 0.8672 - val_categorical_accuracy: 0.8672
# Epoch 73/150
# 69/69 [==============================] - 7s 95ms/step - loss: 0.3409 - acc: 0.8925 - categorical_accuracy: 0.8925 - val_loss: 0.4313 - val_acc: 0.8750 - val_categorical_accuracy: 0.8750
# Epoch 74/150
# 69/69 [==============================] - 7s 96ms/step - loss: 0.3323 - acc: 0.8944 - categorical_accuracy: 0.8944 - val_loss: 0.3818 - val_acc: 0.8672 - val_categorical_accuracy: 0.8672
# Epoch 75/150
# 69/69 [==============================] - 7s 101ms/step - loss: 0.3323 - acc: 0.8989 - categorical_accuracy: 0.8989 - val_loss: 0.3802 - val_acc: 0.8828 - val_categorical_accuracy: 0.8828
# Epoch 76/150
# 69/69 [==============================] - 7s 95ms/step - loss: 0.3346 - acc: 0.8944 - categorical_accuracy: 0.8944 - val_loss: 0.3582 - val_acc: 0.8828 - val_categorical_accuracy: 0.8828
# Epoch 77/150
# 69/69 [==============================] - 7s 95ms/step - loss: 0.3558 - acc: 0.8798 - categorical_accuracy: 0.8798 - val_loss: 0.4149 - val_acc: 0.8438 - val_categorical_accuracy: 0.8438
# Epoch 78/150
# 69/69 [==============================] - 7s 95ms/step - loss: 0.3255 - acc: 0.8998 - categorical_accuracy: 0.8998 - val_loss: 0.4116 - val_acc: 0.8672 - val_categorical_accuracy: 0.8672
# Epoch 79/150
# 69/69 [==============================] - 7s 96ms/step - loss: 0.3115 - acc: 0.9007 - categorical_accuracy: 0.9007 - val_loss: 0.3707 - val_acc: 0.8828 - val_categorical_accuracy: 0.8828
# Epoch 80/150
# 69/69 [==============================] - 7s 96ms/step - loss: 0.2885 - acc: 0.9189 - categorical_accuracy: 0.9189 - val_loss: 0.3634 - val_acc: 0.8828 - val_categorical_accuracy: 0.8828
# Epoch 81/150
# 69/69 [==============================] - 7s 95ms/step - loss: 0.3086 - acc: 0.9080 - categorical_accuracy: 0.9080 - val_loss: 0.3908 - val_acc: 0.8672 - val_categorical_accuracy: 0.8672
# Epoch 82/150
# 69/69 [==============================] - 6s 94ms/step - loss: 0.2770 - acc: 0.9281 - categorical_accuracy: 0.9281 - val_loss: 0.3619 - val_acc: 0.8672 - val_categorical_accuracy: 0.8672
# Epoch 83/150
# 69/69 [==============================] - 6s 92ms/step - loss: 0.3100 - acc: 0.9089 - categorical_accuracy: 0.9089 - val_loss: 0.3846 - val_acc: 0.8750 - val_categorical_accuracy: 0.8750
# Epoch 84/150
# 69/69 [==============================] - 6s 92ms/step - loss: 0.3173 - acc: 0.8944 - categorical_accuracy: 0.8944 - val_loss: 0.3748 - val_acc: 0.8750 - val_categorical_accuracy: 0.8750
# Epoch 85/150
# 69/69 [==============================] - 6s 93ms/step - loss: 0.3192 - acc: 0.9080 - categorical_accuracy: 0.9080 - val_loss: 0.3458 - val_acc: 0.8828 - val_categorical_accuracy: 0.8828
# Epoch 86/150
# 69/69 [==============================] - 7s 98ms/step - loss: 0.3131 - acc: 0.8953 - categorical_accuracy: 0.8953 - val_loss: 0.4124 - val_acc: 0.8594 - val_categorical_accuracy: 0.8594

# %%
plt.plot(model_hist.history['loss'], label = 'loss')
plt.plot(model_hist.history['val_loss'], label = 'val_loss')
plt.legend()
plt.show()

plt.plot(model_hist.history['acc'], label = 'acc')
plt.plot(model_hist.history['val_acc'], label = 'val_acc')
plt.legend()
plt.show()

# %%
test_generator.reset()
test_acc = model.evaluate(test_generator)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 9/9 [==============================] - 2s 252ms/step - loss: 0.3566 - acc: 0.8857 - categorical_accuracy: 0.8857

# %%
test_generator2 = test_datagen.flow_from_dataframe(
    dataframe=test,
    directory=None,
    x_col="path",
    y_col="label",
    target_size=target_size,
    color_mode=color_mode,
    class_mode="categorical",
    batch_size=1,
)

for i,idk in enumerate(test_generator2):
    
    plt.imshow(idk[0][0])
    plt.plot()
    
    ans = labels[np.argmax(idk[1])]
    prediction = labels[np.argmax(model.predict(idk[0]))]
    
    print('Ans: ', ans)
    print('Prediction: ', prediction)
    
    if i==0:
        break
# Out:
# Found 140 validated image filenames belonging to 26 classes.
# Ans:  Q
# Prediction:  Q

# %%
from sklearn.metrics import confusion_matrix

_ = lambda __: chr(__+ord('A'))

test_generator.reset()
guess = model.predict(test_generator)
guess = np.argmax(guess, axis=1)
ans = test_generator.classes

guess = list(map(_,guess))
ans = list(map(_,ans))

cm = confusion_matrix(ans,guess, labels=labels)

plt.figure(figsize = (8,8))
sns.heatmap(cm, xticklabels=labels, yticklabels=labels, annot=True)
plt.ylabel("True")
plt.xlabel("Predicted")
plt.plot()
# Out:
# []

# %%
import datetime
now = datetime.datetime.now()
model_name = "VGG16--" + str(int(test_acc[1]*100)) + now.strftime("--%m-%d-%H-%M")+'.h5'

modeldir = os.path.join(os.getcwd(),'Models')
modelname = os.path.join(modeldir,model_name)

if os.path.exists(modeldir):
        model.save(modelname)
else:
    os.makedirs(modeldir)
    model.save(modelname)

print(model_name,"saved")
# Out:
# VGG16--88--08-03-03-29.h5 saved
